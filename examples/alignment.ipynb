# %% [markdown]
# ## Data

# %%
import numpy as np
from kerasy.utils import generateSeq

# %%
n = 150
n_same = 20
seed = 1

# %%
seqX, seqY = generateSeq(size=(2,n), nucleic_acid="RNA", seed=seed)

# %% [markdown]
# ## Needleman-Wunsch-Gotoh

# %%
from kerasy.Bio.alignment import NeedlemanWunshGotoh

# %%
model = NeedlemanWunshGotoh()

# %%
model.load_params()
# Out:
# Loading Parameters from '/Users/iwasakishuto/Github/portfolio/Kerasy/kerasy/utils/default_params/NeedlemanWunshGotoh.json'...

# %%
model.params()
# Out:
# |Parameter    |Value|
# ---------------------
# |match        |    1|
# |mismatch     |   -1|
# |gap_opening  |    5|
# |gap_extension|    1|

# %%
model.align(seqX, seqY)
# Out:
#  DP 22500/22500 [####################] 100.00% - 7.297s  max alignment score: -47.00
# Model: NeedlemanWunshGotoh
# Alignment score: -47.000
#
# ===========================================================================
# A: [000] GAGAAAAACCUCCGAUAGGACCCAUUCUCAUACGUGGAUCGGGUGGCUCUACCUCAACGC [060]
# B: [000] UUUGCACUGUGGGAUUGCCGGGAAUGCAUGAAACACUCUCGGUCAGAAGCUCGUGAGCGU [060]
#
# A: [060] GU-CAGUCUCUACCUG--UACAUAAGUUGCGCACCUCC--GAUCGUACGCCCCAUCUGGG [115]
# B: [060] GUGCAGUCUGGGCCCGACUAAAUAUGUCGUGCAGAUACUUCCUCAUUUAUCUCGACGGCG [120]
#
# A: [115] UAAGUAGGCAAGCUUAUUGUUGGAUGCCUGCCGAG [149]
# B: [120] AGAAGUAUCAAGGUAA-----GGUGUGCUUUCCAG [149]
# ===========================================================================

# %% [markdown]
# ## Backward-Needleman-Wunsch-Gotoh

# %%
from kerasy.Bio.alignment import BackwardNeedlemanWunshGotoh

# %%
model = BackwardNeedlemanWunshGotoh()

# %%
model.load_params()
# Out:
# Loading Parameters from '/Users/iwasakishuto/Github/portfolio/Kerasy/kerasy/utils/default_params/BackwardNeedlemanWunshGotoh.json'...

# %%
model.params()
# Out:
# |Parameter    |Value|
# ---------------------
# |match        |    1|
# |mismatch     |   -1|
# |gap_opening  |    5|
# |gap_extension|    1|

# %%
model.align(seqX, seqY)
# Out:
#  DP 22500/22500 [####################] 100.00% - 7.427s  max alignment score: -44.00
# Model: BackwardNeedlemanWunshGotoh
# Alignment score: -47.000
#
# ===========================================================================
# A: [000] GAGAAAAACCUCCGAUAGGACCCAUUCUCAUACGUGGAUCGGGUGGCUCUACCUCAACGC [060]
# B: [000] UUUGCACUGUGGGAUUGCCGGGAAUGCAUGAAACACUCUCGGUCAGAAGCUCGUGAGCGU [060]
#
# A: [060] GU-CAGUCUCUACCUG--UACAUAAGUUGCGCACCUCCGAUCGUACGCCCCAUCUGGGUA [117]
# B: [060] GUGCAGUCUGGGCCCGACUAAAUAUGUCGUGCAGAUACUUCCUCAUUUAUCUCGACGGCG [120]
#
# A: [117] AGUAGGCAAGCUUAUUGUUGGAUGCCUGCCGA [148]
# B: [120] AGAAGU--AUCAAGGUAAGGUGUGCUUUCC-A [148]
# ===========================================================================

# %% [markdown]
# ## Smith-Waterman-Gotoh

# %%
from kerasy.Bio.alignment import SmithWaterman

# %%
model = SmithWaterman()

# %%
model.load_params()
# Out:
# Loading Parameters from '/Users/iwasakishuto/Github/portfolio/Kerasy/kerasy/utils/default_params/SmithWaterman.json'...

# %%
model.params()
# Out:
# |Parameter    |Value|
# ---------------------
# |match        |    1|
# |mismatch     |   -1|
# |gap_opening  |    5|
# |gap_extension|    1|

# %%
model.align(seqX, seqY)
# Out:
#  DP 22500/22500 [####################] 100.00% - 13.760s  max alignment score: 7.0
# Model: SmithWaterman
# Alignment score: 7.000
#
# ===========================================================================
# A: [075] UACAUAAGUUGCGCA [089]
# B: [078] UAAAUAUGUCGUGCA [092]
# ===========================================================================

# %% [markdown]
# ## Pair HMM

# %%
from kerasy.Bio.alignment import PairHMM

# %%
model = PairHMM()

# %%
model.load_params()
# Out:
# Loading Parameters from '/Users/iwasakishuto/Github/portfolio/Kerasy/kerasy/utils/default_params/PairHMM.json'...
# Converted delta from Fraction to Float.
# Converted epsilon from Fraction to Float.
# Converted tau from Fraction to Float.
# Converted px_e_y from Fraction to Float.
# Converted px_ne_y from Fraction to Float.
# Converted qx from Fraction to Float.
# Converted qy from Fraction to Float.

# %%
model.params()
# Out:
# |Parameter|               Value|
# --------------------------------
# |delta    |                 0.1|
# |epsilon  |                 0.2|
# |tau      | 0.03333333333333333|
# |px_e_y   |               0.125|
# |px_ne_y  |0.041666666666666664|
# |qx       |                0.25|
# |qy       |                0.25|

# %%
model.align(seqX, seqY)
# Out:
#  Viterbi 00589/22500 [--------------------]   2.62% - 0.208s  max alignment score: -413.11128857887957
#  Viterbi 01039/22500 [--------------------]   4.62% - 0.435s  max alignment score: -411.85267306101605
#  Viterbi 01383/22500 [#-------------------]   6.15% - 0.632s  max alignment score: -95.24366112376639
#  Viterbi 01901/22500 [#-------------------]   8.45% - 0.864s  max alignment score: -295.49761563023765
#  Viterbi 02419/22500 [##------------------]  10.75% - 1.067s  max alignment score: -59.79822011894258
#  Viterbi 02573/22500 [##------------------]  11.44% - 1.271s  max alignment score: -70.78007867332659
#  Viterbi 03048/22500 [##------------------]  13.55% - 1.477s  max alignment score: -134.81494146875173
#  Viterbi 03478/22500 [###-----------------]  15.46% - 1.745s  max alignment score: -85.84419869081394
#  Viterbi 04113/22500 [###-----------------]  18.28% - 1.930s  max alignment score: -179.87894383619783
#  Viterbi 04466/22500 [###-----------------]  19.85% - 2.242s  max alignment score: -334.2256413730675
#  Viterbi 04655/22500 [####----------------]  20.69% - 2.466s  max alignment score: -93.7091072116901
#  Viterbi 04954/22500 [####----------------]  22.02% - 2.687s  max alignment score: -99.25254703627114
#  Viterbi 05468/22500 [####----------------]  24.30% - 2.897s  max alignment score: -195.88167291315804
#  Viterbi 05927/22500 [#####---------------]  26.34% - 3.099s  max alignment score: -221.58464785728046
#  Viterbi 06240/22500 [#####---------------]  27.73% - 3.328s  max alignment score: -256.62530259575556
#  Viterbi 06653/22500 [#####---------------]  29.57% - 3.533s  max alignment score: -160.54619617716878
#  Viterbi 07092/22500 [######--------------]  31.52% - 3.781s  max alignment score: -145.0343908580342
#  Viterbi 07274/22500 [######--------------]  32.33% - 3.987s  max alignment score: -212.52290645714046
#  Viterbi 07571/22500 [######--------------]  33.65% - 4.158s  max alignment score: -203.73861190097242
#  Viterbi 08131/22500 [#######-------------]  36.14% - 4.411s  max alignment score: -160.1475315732428
#  Viterbi 08545/22500 [#######-------------]  37.98% - 4.671s  max alignment score: -416.196112340575
#  Viterbi 08993/22500 [#######-------------]  39.97% - 4.914s  max alignment score: -409.35149738371166
#  Viterbi 09202/22500 [########------------]  40.90% - 5.083s  max alignment score: -183.64682085672666
#  Viterbi 09544/22500 [########------------]  42.42% - 5.394s  max alignment score: -270.65670652923166
